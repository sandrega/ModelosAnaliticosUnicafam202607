# %% [markdown]
# <a href="https://colab.research.google.com/github/sandrega/ModelosAnaliticosUnicafam202607/blob/main/CLASE_1_IPYNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCCION A PYTHON**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DODENTE:NICOLAS MOJICA
#
# ESTUDIANTE:SAUL ANDRES GARCIA

# %% [markdown]
# ## COMENTARIOS DE CODIGOS

# %%
#ESTE ES UN COMENTARIO DE UNA SOLA LINEA
print("hola mundo")
# Out:
# hola mundo

# %%
"""""
ESTE ES
UN COMENTARIO
DE VARIAS LINEAS
"""
# Out:
# '""\nESTE ES\nUN COMENTARIO\nDE VARIAS LINEAS\n'

# %% [markdown]
# ## VARIABLES

# %%
var="hola mundo"
print(var)
# Out:
# hola mundo

# %%
#1.LAS VARIABLES DEBEN SER MINUSCULA
#2.LAS VARIABLES NO DEBEN TENER ESPACIO
#3.LAS VARIABLES NO DEBEN CONTENER CARACTERES ESPECIALES

# %% [markdown]
# ## TIPOS DE DATOS

# %%
# ENTEROS
entero=5
entero_explicito=int(5)

#DECIMALES
decimal=5.0
decimal_explicito=float(5.0)

# %%
type(entero)
# Out:
# int

# %% [markdown]
# ## OPERADORES ARITMETICOS

# %%
a=10
b=5
c=a+b
print(a+b)
print(c)
# Out:
# 15
# 15

# %%
#DIVISION ENTERA
print(a//b)
# Out:
# 2

# %%
# MODULO
print(a%b)
# Out:
# 0

# %%
# EXPONENCIACION
print(b**2)
# Out:
# 25

# %%
# ASIGNACION COMPUESTA
b+=2
print(b)
# Out:
# 7

# %% [markdown]
# ## TEXTOS

# %%
cadena="python es genial"
print(cadena[5])
# Out:
# n

# %%
# EXTRAER LA PLABRA PYTHON
print(cadena[0:6])
# Out:
# python

# %%
# EXTRAER LA PLABRA PYTHON
print(cadena[0:18])
# Out:
# python es genial

# %%
# EXTRAER LA PLABRA GENIAL
print(cadena[10:17])
# Out:
# genial

# %%
# CONQUETACION DE VALORES
palabra1="hola"
palabra2="mundo"
print(palabra1+", "+palabra2)
# Out:
# hola, mundo

# %%
# CAMBIOS DE FORMATOS
print(cadena.upper())
# Out:
# PYTHON ES GENIAL

# %%
# CAMBIOS DE FORMATOS
print(cadena.lower())
# Out:
# python es genial
