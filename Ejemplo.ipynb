# %% [markdown]
# <a href="https://colab.research.google.com/github/sandrega/ModelosAnaliticosUnicafam202607/blob/main/Ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TALLER ACTUALIZACION DE DATOS

# %%
# DICCIONARIO CON DATOS BASICOS
estudiante={
    "Nombres":"Saul Andres",
    "Apellidos":"Garcia",
    "Ciudad":"Bogota",
    "Hijos":"No",
    "Carrera":"Ingenieria Industrial"
}

# %%
# CONSTRUCCION DEL MENU
print("----Bienvenido a tu programa de actualizacion de datos----")
print("para comenzar elige la opcion deseada")
print("1.Agregar un dato nuevo")
print("2.Actualizar un dato")
print("3.Eliminar un dato con del")
print("4.Eliminar un dato con pop")
print("5.Consultar un dato")
print("6.Imprimir diccionario completo")
seleccion=int(input("selecciona la opcion deseada:"))
# Out:
# ----Bienvenido a tu programa de actualizacion de datos----
# para comenzar elige la opcion deseada
# 1.Agregar un dato nuevo
# 2.Actualizar un dato
# 3.Eliminar un dato con del
# 4.Eliminar un dato con pop
# 5.Consultar un dato
# 6.Imprimir diccionario completo
# selecciona la opcion deseada:6

# %%
# AGREGAR UN DATO NUEVO
if seleccion==1:
  clave=input("Ingrese la clave deseada:")
  valor=input("Ingrese el valor deseado")

  # AGREGAR UN ELEMENTO NUEVO

  estudiante[clave]=valor
  print("el valor se agrego exitosamente")
  print(estudiante)

  # ACTUALIZAR

elif seleccion==2:
  clave=input("ingrese la clave a actualizar")
  estudiante[clave]=input("ingrese valor nuevo")
  print("el dato fue actualizado con exito")
  print(estudiante)

  # ELIMINAR

elif seleccion==3:
  clave=input("ingrese la clave a eliminar")
  del estudiante[clave]
  print("el dato fue eliminado exitosamente")
  print(estudiante)

elif seleccion==4:
  clave=input("ingrese clave a eliminar")
  estudiante.pop(clave)
  print("el dato fue eliminado exitosamente")
  print(estudiante)

  # CONSULTAR DATO

elif seleccion==5:
  clave=input("ingrese clave a consultar")
  valor=estudiante.get(clave,"no disponible")
  print(f"{clave}:{valor}")

elif seleccion==6:
  print("perfil compelto")
  print(estudiante)

else:
  print("opcion invalidad")
# Out:
# perfil compelto
# {'Nombres': 'Saul Andres', 'Apellidos': 'Garcia', 'Ciudad': 'Bogota', 'Hijos': 'No', 'Carrera': 'Ingenieria Industrial'}
